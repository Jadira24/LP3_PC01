# %% [markdown]
# IMPORTAR LIBRERÍAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# CARGAR EL DATASET

# %%
# Cargar el archivo .csv separado por tabulaciones
dataframe = pd.read_csv('HEPATITISCVirusPacientesDeEgiptoDatosPerdidos.csv', sep= ';')
dataframe.head(10)
# Out:
#    AGE  GENDER  BMI  FEVER  NAUSEA  HEADACHE  DIARRHEA  FATIGUE  JAUNDICE  \
# 0   56       1   35      2       1         1         1        2         2
# 1   46       1   29      1       2         2         1        2         2
# 2   57       1   33      2       2         2         2        1         1
# 3   49       2   33      1       2         1         2        1         2
# 4   59       1   32      1       1         2         1        2         2
# 5   58       2   22      2       2         2         1        2         2
# 6   42       2   26      1       1         2         2        2         2
# 7   48       2   30      1       1         2         2        1         1
# 8   44       1   23      1       1         2         2        2         1
# 9   45       1   30      2       1         2         2        1         1
#
#    EPIGASTRIA_PAIN  ...  ALT 36  ALT 48  ALT_AFTER_24W  RNA_BASE    RNA 4  \
# 0                2  ...       5       5              5    655330   634536
# ...
